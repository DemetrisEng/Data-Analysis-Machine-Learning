# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
# %matplotlib inline 
#plt.style.use('ggplot')
#plt.style.use('default')
#plt.style.use('dark_background')
#plt.style.use('bmh')
import numpy as np
from matplotlib.dates import DateFormatter
import datetime

# %%
df1=pd.read_csv(r'C:\Users\dee\Desktop\Test.csv',encoding= 'unicode_escape')
df1.head(15)
# Out:
#               Date/Time  Var   Var1   Var2  Var3   Var4      Var5  Var6  Var7  \
# 0   2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999  12.4  12.3
# 1   2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999  12.3  12.3
# 2   2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999  12.3  12.3
# 3   2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999  12.4  12.3
# 4   2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999  12.3  12.3
# 5   2020-11-20-14:47:29   80  32.42  23.86  21.0  22.42  8.849999  12.4  12.3
# 6   2020-11-20-14:47:34   80  35.28  23.87  21.0  22.42  8.849999  12.4  12.3
# 7   2020-11-20-14:47:39   80  37.98  23.87  22.2  22.42  8.849999  12.4  12.3
# 8   2020-11-20-14:47:44   80  40.55  23.87  22.2  22.42  8.849999  12.4  12.3
# 9   2020-11-20-14:47:49   80  42.97  23.87  22.2  22.42  8.849999  12.4  12.3
# 10  2020-11-20-14:47:54   80  45.29  23.87  24.1  22.42  8.849999  12.4  12.3
# ...

# %%
df1['Var2'].plot(kind='line')

# %%
df1_help=pd.DataFrame(df1['Date/Time'].str.rsplit('-',1).tolist(),columns=['Date','Time'])

# %%
df1_help.head(10)
# Out:
#          Date      Time
# 0  2020-11-20  14:47:04
# 1  2020-11-20  14:47:09
# 2  2020-11-20  14:47:14
# 3  2020-11-20  14:47:19
# 4  2020-11-20  14:47:24
# 5  2020-11-20  14:47:29
# 6  2020-11-20  14:47:34
# 7  2020-11-20  14:47:39
# 8  2020-11-20  14:47:44
# 9  2020-11-20  14:47:49

# %%
df1['Time']=df1_help['Time']
df1.head()
# Out:
#              Date/Time  Var   Var1   Var2  Var3   Var4      Var5  Var6  Var7  \
# 0  2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999  12.4  12.3
# 1  2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999  12.3  12.3
# 2  2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999  12.3  12.3
# 3  2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999  12.4  12.3
# 4  2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999  12.3  12.3
#
#    Var8      Time
# 0   0.0  14:47:04
# 1   0.0  14:47:09
# 2   0.0  14:47:14
# 3   0.0  14:47:19
# 4   0.0  14:47:24

# %%
#del df1['Date/Time']
df1.head()
# Out:
#              Date/Time  Var   Var1   Var2  Var3   Var4      Var5  Var6  Var7  \
# 0  2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999  12.4  12.3
# 1  2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999  12.3  12.3
# 2  2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999  12.3  12.3
# 3  2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999  12.4  12.3
# 4  2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999  12.3  12.3
#
#    Var8      Time
# 0   0.0  14:47:04
# 1   0.0  14:47:09
# 2   0.0  14:47:14
# 3   0.0  14:47:19
# 4   0.0  14:47:24

# %%
df1['Time']=pd.to_timedelta(df1_help['Time'])

# %%
df1.dtypes
# Out:
# Date/Time             object
# Var                    int64
# Var1                 float64
# Var2                 float64
# Var3                 float64
# Var4                 float64
# Var5                 float64
# Var6                 float64
# Var7                 float64
# Var8                 float64
# Time         timedelta64[ns]
# dtype: object

# %%
df1.head()
# Out:
#              Date/Time  Var   Var1   Var2  Var3   Var4      Var5  Var6  Var7  \
# 0  2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999  12.4  12.3
# 1  2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999  12.3  12.3
# 2  2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999  12.3  12.3
# 3  2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999  12.4  12.3
# 4  2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999  12.3  12.3
#
#    Var8     Time
# 0   0.0 14:47:04
# 1   0.0 14:47:09
# 2   0.0 14:47:14
# 3   0.0 14:47:19
# 4   0.0 14:47:24

# %% [markdown]
# ### Add time to a time

# %%
df1['ActualTime']=df1['Time']+pd.Timedelta(minutes=43)

# %%
df1.head()
# Out:
#              Date/Time  Var   Var1   Var2  Var3   Var4      Var5  Var6  Var7  \
# 0  2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999  12.4  12.3
# 1  2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999  12.3  12.3
# 2  2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999  12.3  12.3
# 3  2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999  12.4  12.3
# 4  2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999  12.3  12.3
#
#    Var8     Time ActualTime
# 0   0.0 14:47:04   15:30:04
# 1   0.0 14:47:09   15:30:09
# 2   0.0 14:47:14   15:30:14
# 3   0.0 14:47:19   15:30:19
# 4   0.0 14:47:24   15:30:24

# %%
df1.set_index('ActualTime',inplace=True)

# %%
df1.reset_index(inplace=True)
df1.head()
# Out:
#   ActualTime            Date/Time  Var   Var1   Var2  Var3   Var4      Var5  \
# 0   15:30:04  2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999
# 1   15:30:09  2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999
# 2   15:30:14  2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999
# 3   15:30:19  2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999
# 4   15:30:24  2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999
#
#    Var6  Var7  Var8     Time
# 0  12.4  12.3   0.0 14:47:04
# 1  12.3  12.3   0.0 14:47:09
# 2  12.3  12.3   0.0 14:47:14
# 3  12.4  12.3   0.0 14:47:19
# 4  12.3  12.3   0.0 14:47:24

# %%
df1.loc[7000:11000,'Var2'].plot(kind='line')

# %%
df1_first=pd.DataFrame(df1.iloc[7000:13000])
df1_first.reset_index(drop=True,inplace=True)
df1_first.head()
df1_first.set_index('ActualTime',inplace=True)
ax=df1_first['Var2'].plot(kind='line',figsize=(20,15))
ax.tick_params(axis='y', which='major', labelsize=12)
ax.tick_params(axis='x', which='major', labelsize=12)
ax.set_xlabel('Time',size=15)
ax.set_ylim(22.5,24.2)
# Out:
# (22.5, 24.2)

# %%
df1.head()
# Out:
#   ActualTime            Date/Time  Var   Var1   Var2  Var3   Var4      Var5  \
# 0   15:30:04  2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999
# 1   15:30:09  2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999
# 2   15:30:14  2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999
# 3   15:30:19  2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999
# 4   15:30:24  2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999
#
#    Var6  Var7  Var8     Time
# 0  12.4  12.3   0.0 14:47:04
# 1  12.3  12.3   0.0 14:47:09
# 2  12.3  12.3   0.0 14:47:14
# 3  12.4  12.3   0.0 14:47:19
# 4  12.3  12.3   0.0 14:47:24

# %%
df1['Date']=df1['Date/Time'].astype('datetime64[ns]')

# %%
df1['Date']=df1['Date']+pd.Timedelta(minutes=43)

# %%
df1.head()
# Out:
#   ActualTime            Date/Time  Var   Var1   Var2  Var3   Var4      Var5  \
# 0   15:30:04  2020-11-20-14:47:04   80  19.12  23.85  20.1  22.42  8.849999
# 1   15:30:09  2020-11-20-14:47:09   80  20.47  23.83  20.1  22.42  8.849999
# 2   15:30:14  2020-11-20-14:47:14   80  23.17  23.83  20.1  22.42  8.849999
# 3   15:30:19  2020-11-20-14:47:19   80  26.29  23.83  20.1  22.42  8.849999
# 4   15:30:24  2020-11-20-14:47:24   80  29.42  23.85  20.1  22.42  8.849999
#
#    Var6  Var7  Var8     Time                Date
# 0  12.4  12.3   0.0 14:47:04 2020-11-20 15:30:04
# 1  12.3  12.3   0.0 14:47:09 2020-11-20 15:30:09
# 2  12.3  12.3   0.0 14:47:14 2020-11-20 15:30:14
# 3  12.4  12.3   0.0 14:47:19 2020-11-20 15:30:19
# 4  12.3  12.3   0.0 14:47:24 2020-11-20 15:30:24

# %%
df1.set_index('Date',inplace=True)
ax0=df1['Var2'].plot(kind='line',figsize=(20,15))
ax0.set_ylim(22.5,24.2)
ax0.tick_params(axis='y', which='major', labelsize=12)
ax0.set_xlabel('Time',size=15)
ax0.tick_params(axis='x', which='major', labelsize=12)
df1.reset_index(inplace=True)

# %%
df1.head()
# Out:
#                  Date ActualTime            Date/Time  Var   Var1   Var2  \
# 0 2020-11-20 15:30:04   15:30:04  2020-11-20-14:47:04   80  19.12  23.85
# 1 2020-11-20 15:30:09   15:30:09  2020-11-20-14:47:09   80  20.47  23.83
# 2 2020-11-20 15:30:14   15:30:14  2020-11-20-14:47:14   80  23.17  23.83
# 3 2020-11-20 15:30:19   15:30:19  2020-11-20-14:47:19   80  26.29  23.83
# 4 2020-11-20 15:30:24   15:30:24  2020-11-20-14:47:24   80  29.42  23.85
#
#    Var3   Var4      Var5  Var6  Var7  Var8     Time
# 0  20.1  22.42  8.849999  12.4  12.3   0.0 14:47:04
# 1  20.1  22.42  8.849999  12.3  12.3   0.0 14:47:09
# 2  20.1  22.42  8.849999  12.3  12.3   0.0 14:47:14
# 3  20.1  22.42  8.849999  12.4  12.3   0.0 14:47:19
# 4  20.1  22.42  8.849999  12.3  12.3   0.0 14:47:24

# %%
df1_second=pd.DataFrame(df1.iloc[32000:40000])
df1_second.reset_index(drop=True,inplace=True)
df1_second.head()
df1_second.set_index('ActualTime',inplace=True)
ax2=df1_second['Var2'].plot(kind='line',figsize=(20,15))
ax2.set_ylim(22.5,24.2)
ax2.tick_params(axis='y', which='major', labelsize=12)
ax2.set_xlabel('Time',size=15)
ax2.tick_params(axis='x', which='major', labelsize=12)
