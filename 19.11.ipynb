# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
# %matplotlib inline 
#plt.style.use('ggplot')
#plt.style.use('default')
#plt.style.use('dark_background')
#plt.style.use('bmh')
import numpy as np
from matplotlib.dates import DateFormatter
import datetime

# %%
df1=pd.read_csv(r'C:\Users\dee\Desktop\Test1.csv',encoding= 'unicode_escape')
df1.head(15)
# Out:
#               Date/Time  Var   Var1   Var2  Var3   Var4  Var5  Var6  Var7  \
# 0   2020-11-19-12:45:21   80  19.18  24.07  20.1  22.42  8.65  12.6  12.5
# 1   2020-11-19-12:45:26   80  20.81  24.07  20.0  22.42  8.65  12.6  12.5
# 2   2020-11-19-12:45:31   80  23.69  24.07  20.0  22.42  8.65  12.7  12.5
# 3   2020-11-19-12:45:36   80  26.88  24.07  20.0  22.42  8.65  12.6  12.5
# 4   2020-11-19-12:45:41   80  29.98  24.08  20.8  22.42  8.65  12.7  12.5
# 5   2020-11-19-12:45:46   80  32.96  24.08  20.8  22.42  8.75  12.7  12.6
# 6   2020-11-19-12:45:51   80  35.80  24.08  23.0  22.42  8.75  12.7  12.6
# 7   2020-11-19-12:45:56   80  38.50  24.08  23.0  22.42  8.75  12.7  12.6
# 8   2020-11-19-12:46:01   80  41.06  24.08  25.9  22.42  8.75  12.7  12.6
# 9   2020-11-19-12:46:06   80  43.51  24.08  25.9  22.42  8.75  12.8  12.6
# 10  2020-11-19-12:46:11   80  45.81  24.08  25.9  22.42  8.75  12.9  12.7
# 11  2020-11-19-12:46:16   80  47.98  24.08  29.0  22.42  8.75  12.9  12.8
# ...

# %%
df1.loc[0,'Var8']=0

# %%
df1.head(3)
# Out:
#              Date/Time  Var   Var1   Var2  Var3   Var4  Var5  Var6  Var7  Var8
# 0  2020-11-19-12:45:21   80  19.18  24.07  20.1  22.42  8.65  12.6  12.5   0.0
# 1  2020-11-19-12:45:26   80  20.81  24.07  20.0  22.42  8.65  12.6  12.5   0.0
# 2  2020-11-19-12:45:31   80  23.69  24.07  20.0  22.42  8.65  12.7  12.5   0.0

# %%
df1_help=pd.DataFrame(df1['Date/Time'].str.rsplit('-',1).tolist(),columns=['Date','Time'])
df1['Time']=df1_help['Time']
df1.head()
# Out:
#              Date/Time  Var   Var1   Var2  Var3   Var4  Var5  Var6  Var7  \
# 0  2020-11-19-12:45:21   80  19.18  24.07  20.1  22.42  8.65  12.6  12.5
# 1  2020-11-19-12:45:26   80  20.81  24.07  20.0  22.42  8.65  12.6  12.5
# 2  2020-11-19-12:45:31   80  23.69  24.07  20.0  22.42  8.65  12.7  12.5
# 3  2020-11-19-12:45:36   80  26.88  24.07  20.0  22.42  8.65  12.6  12.5
# 4  2020-11-19-12:45:41   80  29.98  24.08  20.8  22.42  8.65  12.7  12.5
#
#    Var8      Time
# 0   0.0  12:45:21
# 1   0.0  12:45:26
# 2   0.0  12:45:31
# 3   0.0  12:45:36
# 4  -0.1  12:45:41

# %%
df1['Date']=df1['Date/Time'].astype('datetime64[ns]')
df1.head(2)
# Out:
#              Date/Time  Var   Var1   Var2  Var3   Var4  Var5  Var6  Var7  \
# 0  2020-11-19-12:45:21   80  19.18  24.07  20.1  22.42  8.65  12.6  12.5
# 1  2020-11-19-12:45:26   80  20.81  24.07  20.0  22.42  8.65  12.6  12.5
#
#    Var8      Time                Date
# 0   0.0  12:45:21 2020-11-19 12:45:21
# 1   0.0  12:45:26 2020-11-19 12:45:26

# %%
df1.dtypes
# Out:
# Date/Time            object
# Var                   int64
# Var1                float64
# Var2                float64
# Var3                float64
# Var4                float64
# Var5                float64
# Var6                float64
# Var7                float64
# Var8                float64
# Time                 object
# Date         datetime64[ns]
# dtype: object

# %%
df1.drop(columns='Date/Time',inplace=True)

# %%
df1.set_index('Date',inplace=True)
df1['Var8'].plot(kind='line',figsize=(15,10))

# %%
df1.reset_index(inplace=True)

# %%
df1.reset_index(inplace=True)
df1['Seconds']=df1['index']*5
df1.drop(columns='index',inplace=True)
df1.set_index('Seconds',inplace=True)
df1.head()
# Out:
#                        Date  Var   Var1   Var2  Var3   Var4  Var5  Var6  Var7  \
# Seconds
# 0       2020-11-19 12:45:21   80  19.18  24.07  20.1  22.42  8.65  12.6  12.5
# 5       2020-11-19 12:45:26   80  20.81  24.07  20.0  22.42  8.65  12.6  12.5
# 10      2020-11-19 12:45:31   80  23.69  24.07  20.0  22.42  8.65  12.7  12.5
# 15      2020-11-19 12:45:36   80  26.88  24.07  20.0  22.42  8.65  12.6  12.5
# 20      2020-11-19 12:45:41   80  29.98  24.08  20.8  22.42  8.65  12.7  12.5
#
#          Var8      Time
# Seconds
# 0         0.0  12:45:21
# 5         0.0  12:45:26
# 10        0.0  12:45:31
# 15        0.0  12:45:36
# 20       -0.1  12:45:41

# %%
ax1=df1['Var8'].plot(kind='line',figsize=(20,15),color='red')
ax1.tick_params(axis='both', which='major', labelsize=15)
ax1.grid(color='grey', linestyle='dotted', linewidth=1)
plt.show()

# %%
df1.tail()
# Out:
#                        Date  Var   Var1   Var2  Var3   Var4      Var5  Var6  \
# Seconds
# 86390   2020-11-20 12:45:11   20  19.20  23.72  20.1  22.42  8.849999  13.0
# 86395   2020-11-20 12:45:16   20  19.18  23.72  20.1  22.42  8.849999  13.1
# 86400   2020-11-20 12:45:21   20  19.12  23.71  20.1  22.42  8.849999  13.0
# 86405   2020-11-20 12:45:26   20  19.05  23.72  20.1  22.42  8.849999  13.0
# 86410   2020-11-20 12:45:31   20  19.01  23.71  20.1  22.42  8.849999  13.0
#
#          Var7  Var8      Time
# Seconds
# 86390    12.9  -1.0  12:45:11
# 86395    12.9  -1.0  12:45:16
# 86400    12.9  -1.0  12:45:21
# 86405    12.9  -1.0  12:45:26
# 86410    12.9  -1.0  12:45:31

# %%
abs_time=(28795-10825)/60
abs_time
# Out:
# 299.5

# %%
ax2=df1[['Var','Var1','Var2','Var3']].plot(kind='line',figsize=(20,15))
ax2.tick_params(axis='both', which='major', labelsize=15)
ax2.set_xlabel(' ',fontsize=20)
ax2.grid(color='grey', linestyle='dotted', linewidth=1)
plt.show()

# %%
ax3 = df1[['Var6','Var7']].plot(kind='line',figsize=(20,15))
ax3.set_xlabel(' ',fontsize=20)
ax3.tick_params(axis='both', which='major', labelsize=15)
ax3.grid(color='grey', linestyle='dotted', linewidth=1)
plt.show()

# %%
df1.head()
# Out:
#                        Date  Var   Var1   Var2  Var3   Var4  Var5  Var6  Var7  \
# Seconds
# 0       2020-11-19 12:45:21   80  19.18  24.07  20.1  22.42  8.65  12.6  12.5
# 5       2020-11-19 12:45:26   80  20.81  24.07  20.0  22.42  8.65  12.6  12.5
# 10      2020-11-19 12:45:31   80  23.69  24.07  20.0  22.42  8.65  12.7  12.5
# 15      2020-11-19 12:45:36   80  26.88  24.07  20.0  22.42  8.65  12.6  12.5
# 20      2020-11-19 12:45:41   80  29.98  24.08  20.8  22.42  8.65  12.7  12.5
#
#          Var8      Time
# Seconds
# 0         0.0  12:45:21
# 5         0.0  12:45:26
# 10        0.0  12:45:31
# 15        0.0  12:45:36
# 20       -0.1  12:45:41
